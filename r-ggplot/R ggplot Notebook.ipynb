# %%
library(ggplot2)

carsample <- read.csv(file = 'cars-sample.csv')

# %%
ggplot(carsample, aes(x = Weight, y = MPG)) +
    geom_point(aes(color = Manufacturer, size = Weight),
               alpha = 0.5)
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title
